# %% [markdown]
# # CDSS Model Training
#
# This notebook is a placeholder for exploratory model work. The runnable training pipeline currently lives in `backend/train_model.py` so the demo model can be regenerated from the command line.

# %%
from pathlib import Path

project_root = Path('..').resolve()
project_root

# %% [markdown]
# Next steps for a fuller notebook:
#
# - Load real or synthetic patient data
# - Explore feature distributions
# - Train baseline models
# - Compare metrics
# - Save the selected model to `backend/models/risk_model.pkl`
